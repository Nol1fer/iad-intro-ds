# %% [markdown]
# # Домашнее задание 2 (5 баллов).
#
# Все задания ниже имеют равный вес (5/16).

# %%
import numpy as np
import pandas as pd
import glob

# %% [markdown]
# #### Описание данных
#
# В папке Data находится информация о студентах. Всего 10 групп студентов. Файлы делятся на две категории:
#     * Students_info_i - информация о студентах из группы i
#     * Students_marks_i - оценки студентов из группы i за экзамены

# %% [markdown]
# ### Одно из важных достоинств pandas $-$ это удобные методы реляционного взаимодействия с данными, аналогичные, например, возможностям SQL для слияния и конкатенации таблиц: merge, join, concat. Наличие готовых методов позволяет не реализовывать самостоятельно поэлементную обработку данных и оперировать сразу целыми таблицами данных.
#
# Подробно об этих методах посмотрите тут: https://www.kaggle.com/residentmario/renaming-and-combining#Combining

# %% [markdown]
# #### Задание 1. Соберите всю информацию о студентах в одну таблицу df. В получившейся таблице должна быть информация и оценки всех студентов из всех групп. Напечатайте несколько строк таблицы для демонстрации результата.¶

# %%
path = r'./Data'
info_files = glob.glob(path + "/Students_info_*.csv")

info = pd.concat((pd.read_csv(f) for f in info_files), ignore_index=True)
info.head()

marks_files = glob.glob(path + "/Students_marks_*.csv")

marks = pd.concat((pd.read_csv(f) for f in marks_files), ignore_index=True)
marks.head()

df = pd.merge(info, marks, on="index", how="left")
df.head(10)
df.tail(10)
# Out:
#      index  gender race/ethnicity parental level of education         lunch  \
# 990    990    male        group E                 high school  free/reduced
# 991    991  female        group B            some high school      standard
# 992    992  female        group D          associate's degree  free/reduced
# 993    993  female        group D           bachelor's degree  free/reduced
# 994    994    male        group A                 high school      standard
# 995    995  female        group E             master's degree      standard
# 996    996    male        group C                 high school  free/reduced
# 997    997  female        group C                 high school  free/reduced
# 998    998  female        group D                some college      standard
# 999    999  female        group D                some college  free/reduced
#
#     test preparation course    group  math score  reading score  writing score
# ...

# %% [markdown]
# #### Задание 2. Удалите столбец index у полученной таблицы. Напечатайте первые 10 строк таблицы.

# %%
df = df.drop("index", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = df.drop("index", axis=1)
#       2 df.head()
#
# File c:\Users\mg\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# File c:\Users\mg\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course   group  math score  reading score  writing score
# 0                    none  group1          72             72             74
# 1               completed  group1          69             90             88
# ...

# %% [markdown]
# #### Задание 3. Выведите на экран размеры полученной таблицы

# %%
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Задание 4. Выведите на экран статистические характеристики числовых столбцов таблицы (минимум, максимум, среднее значение, стандартное отклонение)

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.describe(include='object')
# Out:
# C:\Users\mg\AppData\Local\Temp\ipykernel_13224\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course   group
# ...

# %%
df.value_counts()
# Out:
# gender  race/ethnicity  parental level of education  lunch         test preparation course  group    math score  reading score  writing score
# female  group B         bachelor's degree            standard      none                     group1   72          72             74               1
#         group C         some college                 standard      completed                group1   69          90             88               1
#         group B         master's degree              standard      none                     group1   90          95             93               1
# male    group A         associate's degree           free/reduced  none                     group1   47          57             44               1
#         group C         some college                 standard      none                     group1   76          78             75               1
# ...

# %% [markdown]
# #### Задание 5. Проверьте, есть ли в таблице пропущенные значения

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# group                          0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# #### Задание 6. Выведите на экран средние баллы студентов по каждому предмету (math, reading, writing)

# %%
df[['math score','reading score', 'writing score']].mean()
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %% [markdown]
# **Задание 7. Как зависят оценки от того, проходил ли студент курс для подготовки к сдаче экзамена (test preparation course)? Выведите на экран для каждого предмета в отдельности средний балл студентов, проходивших курс для подготовки к экзамену и не проходивших курс.**

# %%
df.groupby(["test preparation course"]).agg(math=("math score", "mean"), reading=("reading score", "mean"), writing=("writing score", "mean"))
# Out:
#                               math    reading    writing
# test preparation course
# completed                69.695531  73.893855  74.418994
# none                     64.077882  66.534268  64.504673

# %% [markdown]
# **Задание 8. Выведите на экран все различные значения из столбца lunch.**

# %%
df["lunch"].unique()
# Out:
# <ArrowStringArray>
# ['standard', 'free/reduced']
# Length: 2, dtype: str

# %% [markdown]
# **Задание 9. Переименуйте колонку "parental level of education" в "education", а "test preparation course" в "test preparation" с помощью метода pandas rename**
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html

# %%
df = df.rename(columns={"parental level of education": "education", "test preparation course": "test preparation"})

# %% [markdown]
# **Зафиксируем минимальный балл для сдачи экзамена**

# %%
passmark = 50

# %% [markdown]
# **Задание 10. Ответьте на вопросы:**
#     * Какая доля студентов сдала экзамен по математике (passmark >= 50)?
#     * Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?
#     * Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?

# %%
len(df[df["math score"] >= passmark]) / len(df)
# Out:
# 0.865

# %%
df2 = df[df["test preparation"] == "completed"]
len(df2[df2["math score"] >= passmark])/len(df2)
# Out:
# 0.9217877094972067

# %%
(df2["math score"] >= passmark).mean()
# Out:
# np.float64(0.9217877094972067)

# %%
df3 = df[df["gender"] == "female"]
df3 = df3[df3["test preparation"] == "none"]
len(df3[df3["math score"] < passmark]) / len(df3)
# Out:
# 0.20958083832335328

# %% [markdown]
# **Задание 11. С помощью groupby выполните задания ниже. Также выведите время выполнения каждого из заданий.**
#     * Для каждой этнической группы выведите средний балл за экзамен по чтению
#     * Для каждого уровня образования выведите минимальный балл за экзамен по письму

# %%
# %%timeit
df.groupby(by="race/ethnicity")["reading score"].mean()
# Out:
# 940 μs ± 108 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
df.groupby(by="education")["writing score"].min()
# Out:
# 856 μs ± 11.1 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# **Задание 12. Выполните задание 11 с помощью циклов. Сравните время выполнения.**

# %%
# %%timeit
# Initialize dictionary to store sums and counts
race_scores = {}

# Loop through each row
for idx, row in df.iterrows():
    race = row["race/ethnicity"]
    score = row["reading score"]
    
    if race not in race_scores:
        race_scores[race] = {"sum": 0, "count": 0}
    
    race_scores[race]["sum"] += score
    race_scores[race]["count"] += 1

# Calculate means
result = {}
for race, data in race_scores.items():
    result[race] = data["sum"] / data["count"]

print(result)
# Out:
# {'group B': 67.35263157894737, 'group C': 69.10344827586206, 'group A': 64.67415730337079, 'group D': 70.03053435114504, 'group E': 73.02857142857142}
# {'group B': 67.35263157894737, 'group C': 69.10344827586206, 'group A': 64.67415730337079, 'group D': 70.03053435114504, 'group E': 73.02857142857142}
# {'group B': 67.35263157894737, 'group C': 69.10344827586206, 'group A': 64.67415730337079, 'group D': 70.03053435114504, 'group E': 73.02857142857142}
# {'group B': 67.35263157894737, 'group C': 69.10344827586206, 'group A': 64.67415730337079, 'group D': 70.03053435114504, 'group E': 73.02857142857142}
# {'group B': 67.35263157894737, 'group C': 69.10344827586206, 'group A': 64.67415730337079, 'group D': 70.03053435114504, 'group E': 73.02857142857142}
# {'group B': 67.35263157894737, 'group C': 69.10344827586206, 'group A': 64.67415730337079, 'group D': 70.03053435114504, 'group E': 73.02857142857142}
# ...

# %% [markdown]
# **Задание 13. Выведите на экран средние баллы студентов по каждому предмету в зависимости от пола и уровня образования. То есть должно получиться количество групп, равных 2 * (число уровней образования), и для каждой такой группы выыведите средний балл по каждому из предметов.**
#
# Это можно сделать с помощью сводных таблиц (pivot_table):
#
# https://www.kaggle.com/kamilpolak/tutorial-how-to-use-pivot-table-in-pandas

# %%
df
# Out:
#      gender race/ethnicity           education         lunch test preparation  \
# 0    female        group B   bachelor's degree      standard             none
# 1    female        group C        some college      standard        completed
# 2    female        group B     master's degree      standard             none
# 3      male        group A  associate's degree  free/reduced             none
# 4      male        group C        some college      standard             none
# ..      ...            ...                 ...           ...              ...
# 995  female        group E     master's degree      standard        completed
# 996    male        group C         high school  free/reduced             none
# 997  female        group C         high school  free/reduced        completed
# 998  female        group D        some college      standard        completed
# 999  female        group D        some college  free/reduced             none
#
# ...

# %%
grouped = pd.pivot_table(df, index=['gender', 'education'], aggfunc={'math score': np.mean, 'reading score': np.mean, 'writing score': np.mean})
grouped
# Out:
#                            math score  reading score  writing score
# gender education
# female associate's degree   65.250000      74.120690      74.000000
#        bachelor's degree    68.349206      77.285714      78.380952
#        high school          59.351064      68.202128      66.691489
#        master's degree      66.500000      76.805556      77.638889
#        some college         65.406780      73.550847      74.050847
#        some high school     59.296703      69.109890      68.285714
# male   associate's degree   70.764151      67.433962      65.405660
#        bachelor's degree    70.581818      68.090909      67.654545
#        high school          64.705882      61.480392      58.539216
#        master's degree      74.826087      73.130435      72.608696
#        some college         69.009259      64.990741      63.148148
#        some high school     67.840909      64.693182      61.375000

# %% [markdown]
# #### Задание 14. Сколько студентов успешно сдали экзамен по математике?
#
# Создайте новый столбец в таблице df под названием Math_PassStatus и запишите в него F, если студент не сдал экзамен по математике (балл за экзамен < passmark), и P иначе.
#
# Посчитайте количество студентов, сдавших и не сдавших экзамен по математике.
#
# Сделайте аналогичные шаги для экзаменов по чтению и письму.

# %%
df["Math_PassStatus"] = df["math score"].apply(lambda score: "F" if score < passmark else "P")

# %%
df["Reading_PassStatus"] = df["reading score"].apply(lambda score: "F" if score < passmark else "P")
df["Writing_PassStatus"] = df["writing score"].apply(lambda score: "F" if score < passmark else "P")

df.sample()
# Out:
#     gender race/ethnicity         education         lunch test preparation  \
# 184   male        group C  some high school  free/reduced        completed
#
#       group  math score  reading score  writing score Math_PassStatus  \
# 184  group2          45             52             49               F
#
#     Reading_PassStatus Writing_PassStatus
# 184                  P                  F

# %%
mc = (df["Math_PassStatus"] == "P").sum()
mr = (df["Reading_PassStatus"] == "P").sum()
mw = (df["Writing_PassStatus"] == "P").sum()
print(mc, mr, mw)
# Out:
# 865 910 886

# %% [markdown]
# #### Задание 15. Сколько студентов успешно сдали все экзамены?
#
# Создайте столбец OverAll_PassStatus и запишите в него для каждого студента 'F', если студент не сдал хотя бы один из трех экзаменов, а иначе 'P'.
#
# Посчитайте количество студентов, которые сдали все экзамены.

# %%
def calculate_total(row):
    return "P" if (row['Math_PassStatus'] == "P" and row['Reading_PassStatus'] == "P" and row['Writing_PassStatus'] == "P") else "F"

df["OverAll_PassStatus"] = df.apply(calculate_total, axis=1)
df.sample(10)
# Out:
#      gender race/ethnicity           education         lunch test preparation  \
# 80   female        group B  associate's degree      standard             none
# 733    male        group D    some high school      standard             none
# 129  female        group A   bachelor's degree      standard             none
# 558  female        group B  associate's degree  free/reduced             none
# 987    male        group E    some high school      standard        completed
# 910    male        group D   bachelor's degree  free/reduced             none
# 208  female        group B        some college  free/reduced             none
# 320  female        group C         high school  free/reduced        completed
# 830  female        group A        some college  free/reduced             none
# 182  female        group E         high school      standard             none
#
#        group  math score  reading score  writing score Math_PassStatus  \
# ...

# %% [markdown]
# #### Задание 16. Переведем баллы в оценки
#
# ### Система перевода баллов в оценки
# ####    больше 90 = A
# ####      80-90 = B
# ####      70-80 = C
# ####      60-70 = D
# ####      50-60 = E
# ####    меньше 50 = F (Fail)
#
# Создайте вспомогательную функцию, которая будет по среднему баллу за три экзамена выставлять оценку студенту по данным выше критериям.
#
# Создайте столбец Grade и запишите в него оценку каждого студента.
#
# Выведите количество студентов, получивших каждую из оценок.
#
# **В случае, если средний балл попадает на границу между оценками (т.е. равен ровно 60, 70 или 80 баллов), вы можете интерпретировать условие на своё усмотрение (т.е. можете поставить за 60 баллов оценку D, а можете - E).**

# %%
def GetGrade(row):
    avg = (row['math score'] + row['reading score'] + row['writing score']) / 3
    grade = "F"
    match avg:
        case x if x > 90:
            grade = "A"
        case x if x <= 90 and x > 80:
            grade = "B"
        case x if x <= 80 and x > 70:
            grade = "C"
        case x if x <= 70 and x > 60:
            grade = "D"
        case x if x <= 60 and x > 50:
            grade = "E"
    return grade

df["Grade"] = df.apply(GetGrade, axis=1)
df.sample(10)
# Out:
#      gender race/ethnicity           education         lunch test preparation  \
# 304  female        group C  associate's degree      standard        completed
# 580  female        group D    some high school      standard             none
# 457    male        group D  associate's degree  free/reduced             none
# 243    male        group E        some college      standard             none
# 970  female        group D   bachelor's degree      standard             none
# 71     male        group D        some college      standard        completed
# 496  female        group C        some college      standard             none
# 560  female        group D        some college      standard        completed
# 711  female        group E    some high school      standard        completed
# 11     male        group D  associate's degree      standard             none
#
#        group  math score  reading score  writing score Math_PassStatus  \
# ...

# %%
df.groupby("Grade")["gender"].count()
# Out:
# Grade
# A     50
# B    144
# C    253
# D    260
# F    293
# Name: gender, dtype: int64
